# %%
import numpy as np
import pandas as pd

# %%
array_2d = np.array([[1,2,'A'], [3,4,'B'], [5,6,'C'], [7,8,'B']])
array_2d
# Out:
# array([['1', '2', 'A'],
#        ['3', '4', 'B'],
#        ['5', '6', 'C'],
#        ['7', '8', 'B']], dtype='<U21')

# %%
df = pd.DataFrame(array_2d)
df
# Out:
#    0  1  2
# 0  1  2  A
# 1  3  4  B
# 2  5  6  C
# 3  7  8  B

# %%
df[2].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df[2].value_counts()
# Out:
# B    2
# C    1
# A    1
# Name: 2, dtype: int64
