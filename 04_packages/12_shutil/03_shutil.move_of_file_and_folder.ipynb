# %%
# !mkdir tmp

# %%
# !touch tmp/1.txt

# %%
# !tree
# Out:
# .
# ├── 01_shutil.copy_of_file.ipynb
# ├── 02_shutil.copytree_of_folder.ipynb
# ├── 03_shutil.move_of_file.ipynb
# ├── reNumberFiles.sh
# └── tmp
#     └── 1.txt
#
# 1 directory, 5 files

# %%
import shutil

# %%
shutil.move("tmp/1.txt", "tmp/2.txt")
# Out:
# 'tmp/2.txt'

# %%
# !tree
# Out:
# .
# ├── 01_shutil.copy_of_file.ipynb
# ├── 02_shutil.copytree_of_folder.ipynb
# ├── 03_shutil.move_of_file.ipynb
# ├── reNumberFiles.sh
# └── tmp
#     └── 2.txt
#
# 1 directory, 5 files

# %%
shutil.move("tmp", "tmp2")
# Out:
# 'tmp2'

# %%
# !tree
# Out:
# .
# ├── 01_shutil.copy_of_file.ipynb
# ├── 02_shutil.copytree_of_folder.ipynb
# ├── 03_shutil.move_of_file.ipynb
# ├── reNumberFiles.sh
# └── tmp2
#     └── 2.txt
#
# 1 directory, 5 files

# %%
# !rm -rf tmp2
