# %%
import glob

# %%
# !mkdir test
# !mkdir test/sub1
# !mkdir test/sub1/ssub1
# !touch test/sub1/ssub1/1.txt
# !mkdir test/sub2
# !touch test/sub2/2.txt
# Out:
# mkdir: test: File exists
# mkdir: test/sub1: File exists
# mkdir: test/sub1/ssub1: File exists
# mkdir: test/sub2: File exists

# %%
# !tree
# Out:
# .
# ├── 01_find_folder_and_file_by_glob.ipynb
# └── test
#     ├── sub1
#     │   └── ssub1
#     │       └── 1.txt
#     └── sub2
#         └── 2.txt
#
# 4 directories, 3 files

# %%
glob.glob('./test/sub*/')
# Out:
# ['./test/sub1/', './test/sub2/']

# %%
glob.glob('./test/sub*/*.txt')
# Out:
# ['./test/sub2/2.txt']

# %%
# !rm -rf ./test
