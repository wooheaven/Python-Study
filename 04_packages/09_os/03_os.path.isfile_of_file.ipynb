# %%
# !touch 1.txt

# %%
# !ls -als
# Out:
# total 24
# 4 drwxrwxr-x  3 ubuntu ubuntu 4096  6월 11 07:27 .
# 4 drwxrwxr-x 15 ubuntu ubuntu 4096  6월 10 20:27 ..
# 4 -rw-rw-r--  1 ubuntu ubuntu 1619  6월 10 20:27 01_os.chmod_of_file.ipynb
# 4 -rw-rw-r--  1 ubuntu ubuntu 2491  6월 11 07:26 02_os.path.exists_of_file.ipynb
# 4 -rw-rw-r--  1 ubuntu ubuntu 2491  6월 11 07:26 03_os.path.isfile_of_file.ipynb
# 0 -rw-rw-r--  1 ubuntu ubuntu    0  6월 11 07:27 1.txt
# 4 drwxrwxr-x  2 ubuntu ubuntu 4096  6월 11 07:26 .ipynb_checkpoints

# %%
import os

# %%
os.path.isfile("1.txt")
# Out:
# True

# %%
# !rm 1.txt
